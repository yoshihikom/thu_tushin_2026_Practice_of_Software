# %%
from openai import OpenAI
client = OpenAI(api_key='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')

completion = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {"role": "developer", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Hello!"}
  ]
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='Hello! How can I assist you today?', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)

# %%
import openai

client = openai.OpenAI(api_key="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")

response = client.chat.completions.create(
    model="gpt-4o",  # 使用するモデルを指定
    messages=[
        {"role": "system", "content": "あなたは親切なIT専門のAIアシスタントです。"},
        {"role": "user", "content": "Chat Completions APIのメリットを3つ教えて。"}
    ],
    temperature=0.7 # 応答のランダム性を調整
)

# AIの返答テキストを抽出
print(response.choices[0]) #.message.content)
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Chat Completions APIのメリットは以下の3つです。\n\n1. **自然な対話生成**:\n   - Chat Completions APIは、ユーザーとの自然な対話を生成することに特化しています。ユーザーからの複雑な質問や要求に対して、流暢で人間らしい回答を提供できます。これにより、カスタマーサポートやバーチャルアシスタントなどの用途で、より良いユーザーエクスペリエンスを実現できます。\n\n2. **コンテキストの維持**:\n   - このAPIは、会話のコンテキストを保持し、前後の文脈に基づいて適切な応答を生成することができます。これにより、継続的で一貫性のある会話が可能となり、ユーザーとのインタラクションがスムーズになります。\n\n3. **カスタマイズとスケーラビリティ**:\n   - 開発者は、特定の用途や業種に応じてAPIをカスタマイズすることができます。加えて、クラウドベースのサービスであるため、必要に応じてスケールアップやスケールダウンが容易にでき、大量のリクエストにも対応可能です。これにより、さまざまなビジネスニーズに柔軟に対応できます。\n\nこれらのメリットにより、Chat Completions APIは多くのビジネスやアプリケーションで効果的に活用されています。', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))
